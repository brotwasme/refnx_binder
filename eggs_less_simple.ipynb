# %%
from refnx.dataset import Data1D
from refnx.dataset import ReflectDataset
import refnx
import data_in
data = data_in.data_in('d2o/29553_54.dat')
#print(data)
# dataset = data # ...
data = Data1D(data) 
#print(data)
# Out:
# csv
# cvs-collecting

# %%
from refnx.reflect import SLD, Erf
# simple setup, no tilt, equation or checking
air = SLD(value=0+0j, name='air')

polymer = SLD(4.1,'polymer')
#air-polymer roughness of 0, polymer size of 40.5
polymer_dry = polymer(17.5, 0)
polymer_dry.thick.setp(vary=True,bounds=(11,24))
polymer_dry.sld.real.setp(vary=True,bounds=(1.92,6.21))

polymer_wet = polymer(13, 0)
polymer_wet.thick.setp(vary=True,bounds=(0.1,26))
polymer_wet.rough.setp(vary=True,bounds=(0,15))
polymer_wet.sld.real.setp(vary=True,bounds=(1.92,6.21))
polymer_wet.vfsolv.setp(vary=True, bounds=(0,1))

water = SLD(3.5,'water')
water = water(0,0)
water.sld.real.setp(vary=True,bounds=(-0.56,6.35))

structure = air | polymer_dry | polymer_wet | water
 #air-polymer roughness of 4, polymer size of 55
 #Erf()  <-error function
structure[1].interfaces = Erf() # air-polymer interface
structure[3].interfaces = Erf()
print(structure)
# Out:
# ________________________________________________________________________________
# Structure:
# solvent: None
# reverse structure: False
# contract: 0
#
# ________________________________________________________________________________
# Parameters:      'air'
# <Parameter: 'air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:    'polymer'
# <Parameter:'polymer - thick', value=17.5          , bounds=[11, 24]>
# <Parameter:'polymer - sld', value=4.1          , bounds=[1.92, 6.21]>
# <Parameter:'polymer - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'polymer - rough', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'polymer - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:    'polymer'
# <Parameter:'polymer - thick', value=13          , bounds=[0.1, 26]>
# <Parameter:'polymer - sld', value=4.1          , bounds=[1.92, 6.21]>
# <Parameter:'polymer - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'polymer - rough', value=0          , bounds=[0, 15]>
# <Parameter:'polymer - volfrac solvent', value=0          , bounds=[0, 1]>
# ________________________________________________________________________________
# Parameters:     'water'
# <Parameter:'water - thick', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'water - sld' , value=3.5          , bounds=[-0.56, 6.35]>
# <Parameter:'water - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'water - rough', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'water - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>

# %%
from refnx.reflect import ReflectModel
model = ReflectModel(structure, bkg=0, dq=0)
model.scale.setp(vary=True, bounds=(-1, 1.5))
model.bkg.setp(vary=True,bounds=(-1, 1.5))
#print(model)

# %%
from refnx.analysis import CurveFitter, Objective
objective = Objective(model, data)
fitter = CurveFitter(objective)
fitter.fit('differential_evolution')
print(objective,'\n')
#print(fitter)
# Out:
# ________________________________________________________________________________
# Objective - 2479458310576
# Dataset = <None>, 68 points
# datapoints = 68
# chi2 = 2160.153433002687
# Weighted = True
# Transform = None
# ________________________________________________________________________________
# Parameters:       ''
# ________________________________________________________________________________
# Parameters: 'instrument parameters'
# <Parameter:    'scale'    , value=0.699234 +/- 0.0011, bounds=[-1, 1.5]>
# <Parameter:     'bkg'     , value=3.94644e-06 +/- 4.83e-07, bounds=[-1, 1.5]>
# <Parameter:'dq - resolution', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'Structure - '
# ________________________________________________________________________________
# Parameters:      'air'
# <Parameter: 'air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:    'polymer'
# <Parameter:'polymer - thick', value=23.5491   +/- 3  , bounds=[11, 24]>
# <Parameter:'polymer - sld', value=3.61464 +/- 1.26 , bounds=[1.92, 6.21]>
# <Parameter:'polymer - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'polymer - rough', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'polymer - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:    'polymer'
# <Parameter:'polymer - thick', value=19.108 +/- 3.61 , bounds=[0.1, 26]>
# <Parameter:'polymer - sld', value=3.61464 +/- 1.26 , bounds=[1.92, 6.21]>
# <Parameter:'polymer - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'polymer - rough', value=8.50854  +/- 18  , bounds=[0, 15]>
# <Parameter:'polymer - volfrac solvent', value=0.771979 +/- 0.474, bounds=[0, 1]>
# ________________________________________________________________________________
# Parameters:     'water'
# <Parameter:'water - thick', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'water - sld' , value=6.35 +/- 0.00428, bounds=[-0.56, 6.35]>
# <Parameter:'water - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'water - rough', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'water - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
objective.plot()
plt.yscale('log')
plt.xscale('log')
plt.xlabel('Q')
plt.ylabel('Reflectivity')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %%
print(structure)
# Out:
# ________________________________________________________________________________
# Structure:
# solvent: None
# reverse structure: False
# contract: 0
#
# ________________________________________________________________________________
# Parameters:      'air'
# <Parameter: 'air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:    'polymer'
# <Parameter:'polymer - thick', value=23.5491   +/- 3  , bounds=[11, 24]>
# <Parameter:'polymer - sld', value=3.61464 +/- 1.26 , bounds=[1.92, 6.21]>
# <Parameter:'polymer - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'polymer - rough', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'polymer - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:    'polymer'
# <Parameter:'polymer - thick', value=19.108 +/- 3.61 , bounds=[0.1, 26]>
# <Parameter:'polymer - sld', value=3.61464 +/- 1.26 , bounds=[1.92, 6.21]>
# <Parameter:'polymer - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'polymer - rough', value=8.50854  +/- 18  , bounds=[0, 15]>
# <Parameter:'polymer - volfrac solvent', value=0.771979 +/- 0.474, bounds=[0, 1]>
# ________________________________________________________________________________
# Parameters:     'water'
# <Parameter:'water - thick', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'water - sld' , value=6.35 +/- 0.00428, bounds=[-0.56, 6.35]>
# <Parameter:'water - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'water - rough', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'water - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
