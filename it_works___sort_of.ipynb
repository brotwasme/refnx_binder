# %%
import refnx
refnx.test()
#test complete
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.7.3, pytest-5.0.1, py-1.8.0, pluggy-0.12.0
# rootdir: C:\Users\John\Documents\programing\summer2019
# collected 227 items
#
# _lib\test\test_import.py .                                               [  0%]
# _lib\test\test_util.py .....                                             [  2%]
# analysis\test\test_bounds.py .....                                       [  4%]
# analysis\test\test_curvefitter.py ..F.........                             [ 10%]
# analysis\test\test_globalfitting.py ...                                    [ 11%]
# analysis\test\test_model.py ..                                             [ 12%]
# analysis\test\test_objective.py .................X                         [ 20%]
# analysis\test\test_parameter.py ..................                         [ 28%]
# dataset\test\test_reflectdataset.py ..............                         [ 34%]
# ...
